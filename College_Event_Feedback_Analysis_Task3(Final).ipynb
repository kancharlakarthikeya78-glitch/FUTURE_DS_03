# %% [markdown]
# # College Event Feedback Analysis
#
# Future Interns – Task 3

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
sns.set()

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('college_event_feedback.csv')
df.head()
# Out:
#       Event_Name Event_Type Department  Rating  \
# 0  Tech Workshop   Workshop        CSE       5
# 1  Cultural Fest   Cultural       Arts       4
# 2     AI Seminar    Seminar         IT       3
# 3  Tech Workshop   Workshop        CSE       4
# 4  Cultural Fest   Cultural       Arts       5
#
#                          Feedback_Comment
# 0     Amazing workshop, very informative!
# 1         Loved the performances and vibe
# 2  Content was average, could be improved
# 3  Good explanations and hands-on session
# 4             Best event of the semester!

# %% [markdown]
# ## 3. Rating Analysis

# %%
df.groupby('Event_Name')['Rating'].mean().plot(kind='bar')
plt.title('Average Rating per Event')
plt.show()

# %% [markdown]
# ## 4. Sentiment Analysis

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['Sentiment_Score'] = df['Feedback_Comment'].apply(get_sentiment)
df['Sentiment'] = df['Sentiment_Score'].apply(lambda x: 'Positive' if x > 0 else 'Negative' if x < 0 else 'Neutral')
df.head()
# Out:
#       Event_Name Event_Type Department  Rating  \
# 0  Tech Workshop   Workshop        CSE       5
# 1  Cultural Fest   Cultural       Arts       4
# 2     AI Seminar    Seminar         IT       3
# 3  Tech Workshop   Workshop        CSE       4
# 4  Cultural Fest   Cultural       Arts       5
#
#                          Feedback_Comment  Sentiment_Score Sentiment
# 0     Amazing workshop, very informative!            0.425  Positive
# 1         Loved the performances and vibe            0.700  Positive
# 2  Content was average, could be improved           -0.150  Negative
# 3  Good explanations and hands-on session            0.700  Positive
# 4             Best event of the semester!            1.000  Positive

# %% [markdown]
# ## 5. Sentiment Distribution

# %%
df['Sentiment'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Sentiment Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 6. Insights & Recommendations
# - Workshops received high satisfaction
# - Cultural events were most liked
# - Seminars need better engagement

# %% [markdown]
# ## 🛠 Tools & Libraries Used
#
# - Google Colab
# - Python
# - pandas (data handling)
# - matplotlib & seaborn (visualization)
# - TextBlob (sentiment analysis)

# %% [markdown]
# ## 🔍 Additional Insights
#
# - Events with higher ratings generally showed positive sentiment in feedback comments
# - Negative feedback was mainly observed for seminars, indicating a need for better engagement
# - Workshops and cultural events consistently performed better across both ratings and sentiment

# %% [markdown]
# ## ✅ Conclusion
#
# This analysis demonstrates how student feedback data can be transformed into meaningful insights using data science techniques.
# The results can help event organizers improve planning, engagement, and overall student satisfaction in future college events.
